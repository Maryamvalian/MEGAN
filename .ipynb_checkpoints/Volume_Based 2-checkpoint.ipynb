# %%
from pathlib import Path
from eelbrain import *
from matplotlib import pyplot
import mne
import numpy as np
import re


# %run experiment.py           #e is the experiment object
# Out:
# INFO    :  *** Experiment initialized with root /Users/maryamvalian/Data on 2025-04-22 17:35:31 ***
# DEBUG   :  Using eelbrain 0.40.dev0, mne 1.9.0.
# DEBUG   :  Outdated cache files:
# DEBUG   :  No existing cache files affected.

# %%
e.sessions
# Out:
# ('words', 'sentences', 'emptyroom')

# %%
"""inv_info = 'vec-3-dSPM-0'      #vector, or snr3, dspm, 0: superficial dipoles
src_info = 'vol-10' # set up at vol-10 for testing, set to 5 for better result: Distance between the two adjacent dipoles
e.set_inv(ori=re.split('-',inv_info)[0], 
                snr=int(re.split('-',inv_info)[1]), 
                method=re.split('-',inv_info)[2], 
                depth=int(re.split('-',inv_info)[3]), 
                pick_normal=False, 
                src=src_info)
                """
e.inv_str('vec', snr=6, method='MNE', depth=0)
e.set(parc = 'aparc+aseg')

wholebrain_cortical_subcortical_mask = [
 'Left-Cerebral-White-Matter',
 'Left-Lateral-Ventricle',
 'Left-Inf-Lat-Vent',
 'Left-Putamen',
 'Left-Hippocampus',
 'Left-Amygdala',
 'Left-Accumbens-area',
 'Left-vessel',
 'Right-Cerebral-White-Matter',
 'Right-Inf-Lat-Vent',
 'Right-Putamen',
 'Right-Hippocampus',
 'Right-Amygdala',
 'ctx-lh-bankssts',
 'ctx-lh-caudalanteriorcingulate',
 'ctx-lh-caudalmiddlefrontal',
 'ctx-lh-cuneus',
 'ctx-lh-entorhinal',
 'ctx-lh-fusiform',
 'ctx-lh-inferiorparietal',
 'ctx-lh-inferiortemporal',
 'ctx-lh-isthmuscingulate',
 'ctx-lh-lateraloccipital',
 'ctx-lh-lateralorbitofrontal',
 'ctx-lh-lingual',
 'ctx-lh-medialorbitofrontal',
 'ctx-lh-middletemporal',
 'ctx-lh-parahippocampal',
 'ctx-lh-paracentral',
 'ctx-lh-parsopercularis',
 'ctx-lh-parsorbitalis',
 'ctx-lh-parstriangularis',
 'ctx-lh-pericalcarine',
 'ctx-lh-postcentral',
 'ctx-lh-posteriorcingulate',
 'ctx-lh-precentral',
 'ctx-lh-precuneus',
 'ctx-lh-rostralanteriorcingulate',
 'ctx-lh-rostralmiddlefrontal',
 'ctx-lh-superiorfrontal',
 'ctx-lh-superiorparietal',
 'ctx-lh-superiortemporal',
 'ctx-lh-supramarginal',
 'ctx-lh-frontalpole',
 'ctx-lh-temporalpole',
 'ctx-lh-transversetemporal',
 'ctx-lh-insula',
 'ctx-rh-bankssts',
 'ctx-rh-caudalanteriorcingulate',
 'ctx-rh-caudalmiddlefrontal',
 'ctx-rh-cuneus',
 'ctx-rh-entorhinal',
 'ctx-rh-fusiform',
 'ctx-rh-inferiorparietal',
 'ctx-rh-inferiortemporal',
 'ctx-rh-isthmuscingulate',
 'ctx-rh-lateraloccipital',
 'ctx-rh-lateralorbitofrontal',
 'ctx-rh-lingual',
 'ctx-rh-medialorbitofrontal',
 'ctx-rh-middletemporal',
 'ctx-rh-parahippocampal',
 'ctx-rh-paracentral',
 'ctx-rh-parsopercularis',
 'ctx-rh-parsorbitalis',
 'ctx-rh-parstriangularis',
 'ctx-rh-pericalcarine',
 'ctx-rh-postcentral',
 'ctx-rh-posteriorcingulate',
 'ctx-rh-precentral',
 'ctx-rh-precuneus',
 'ctx-rh-rostralanteriorcingulate',
 'ctx-rh-rostralmiddlefrontal',
 'ctx-rh-superiorfrontal',
 'ctx-rh-superiorparietal',
 'ctx-rh-superiortemporal',
 'ctx-rh-supramarginal',
 'ctx-rh-frontalpole',
 'ctx-rh-temporalpole',
 'ctx-rh-transversetemporal',
 'ctx-rh-insula']



mask = wholebrain_cortical_subcortical_mask

# %%
sessions = ['word']
e.epochs
# Out:
# {'word': PrimaryEpoch('words', tmax=0.8, samplingrate=250, baseline=(None, 0)),
#  'word-real': SecondaryEpoch('word', "word == 'real'"),
#  'word-stem': SecondaryEpoch('word', "inflected == 'uninflected'"),
#  'word-inflected': SecondaryEpoch('word', "inflected == 'inflected'"),
#  'cov': SecondaryEpoch('word', tmax=0),
#  'sentence': PrimaryEpoch('sentences', tmax=1.0, samplingrate=250, baseline=(None, 0)),
#  'sentence-shared': SecondaryEpoch('sentence', "violation != 'grammatical'"),
#  'sentence-none': SecondaryEpoch('sentence', "violation == 'none'"),
#  'sentence-semantic': SecondaryEpoch('sentence', "violation == 'semantic'")}

# %%
epochs=['word-real','word-stem','word-inflected']
#group='young'
group='small'

# %%
e.show_subjects()
# Out:
# #    subject   mri
# ---------------------------------------------
# 0    R0240     fsaverage * 0.9046130902612369
# 1    R0284     fsaverage * 0.8345097578227244
# 2    R0645     fsaverage * 0.8831630078745408
# 3    R0654     fsaverage * 0.847076641686781
# 4    R0656     fsaverage * 0.85956389422857
# 5    R0727     fsaverage * 0.8815395149982078
# 6    R0728     fsaverage * 0.8197895120408497
# 7    R0729     fsaverage * 0.8788670160653236
# 8    R0730     fsaverage * 0.868407292537382
# 9    R0734     fsaverage * 0.8487684940882592
# 10   R0773     fsaverage * 0.9087086286294076
# 11   R0793     fsaverage * 0.8533749683012595
# 12   R0885     fsaverage * 0.8973525478623752
# 13   R0918     fsaverage * 0.9223230124868819
# ---------------------------------------------
# Subjects in group young

# %%
results={}
for epoch in epochs:
    for session in sessions:
        e.set(raw='n-ica', epoch=epoch, rej='')
        
        result=e.load_evoked_stc(
            subjects=group, 
            baseline=False,
            cov='emptyroom', 
            model='word',
           )
        results[f'{epoch}_{session}'] = result
# Out:
# DEBUG   :  Make evoked /Users/maryamvalian/Data/eelbrain-cache/evoked/R0730/n-ica word-real word-ave.fif
# DEBUG   :  Extracting events for n-ica R0730 words
# INFO    :  Raw tsss: computing Maxwell filter for R0730/words
# INFO    :  Raw n-1-20: filtering for R0730/words...
# DEBUG   :  Raw n-ica: applying ICA for R0730/words...
# DEBUG   :  Make evoked /Users/maryamvalian/Data/eelbrain-cache/evoked/R0734/n-ica word-real word-ave.fif
# DEBUG   :  Extracting events for n-ica R0734 words
# INFO    :  Raw tsss: computing Maxwell filter for R0734/words
# INFO    :  Raw n-1-20: filtering for R0734/words...
# DEBUG   :  Raw n-ica: applying ICA for R0734/words...
# DEBUG   :  Make evoked /Users/maryamvalian/Data/eelbrain-cache/evoked/R0773/n-ica word-real word-ave.fif
# DEBUG   :  Extracting events for n-ica R0773 words
# INFO    :  Raw tsss: computing Maxwell filter for R0773/words
# INFO    :  Raw n-1-20: filtering for R0773/words...
# DEBUG   :  Raw n-ica: applying ICA for R0773/words...
# DEBUG   :  Make evoked /Users/maryamvalian/Data/eelbrain-cache/evoked/R0793/n-ica word-real word-ave.fif
# DEBUG   :  Extracting events for n-ica R0793 words
# INFO    :  Raw tsss: computing Maxwell filter for R0793/words
# INFO    :  Raw n-1-20: filtering for R0793/words...
# DEBUG   :  Raw n-ica: applying ICA for R0793/words...
# DEBUG   :  Make evoked /Users/maryamvalian/Data/eelbrain-cache/evoked/R0885/n-ica word-real word-ave.fif
# DEBUG   :  Extracting events for n-ica R0885 words
# INFO    :  Raw tsss: computing Maxwell filter for R0885/words
# INFO    :  Raw n-1-20: filtering for R0885/words...
# DEBUG   :  Raw n-ica: applying ICA for R0885/words...
# DEBUG   :  Make evoked /Users/maryamvalian/Data/eelbrain-cache/evoked/R0918/n-ica word-real word-ave.fif
# DEBUG   :  Extracting events for n-ica R0918 words
# INFO    :  Raw tsss: computing Maxwell filter for R0918/words
# INFO    :  Raw n-1-20: filtering for R0918/words...
# DEBUG   :  Raw n-ica: applying ICA for R0918/words...
# Localize:   0%|          | 0/14 [00:00<?, ?it/s]
# DEBUG   :  Raw n-ica: applying ICA for R0656/sentences...
# DEBUG   :  make_fwd sentences-R0656-ico-4-fwd.fif...
# DEBUG   :  Raw n-ica: applying ICA for R0727/sentences...
# DEBUG   :  make_fwd sentences-R0727-ico-4-fwd.fif...
# DEBUG   :  Raw n-ica: applying ICA for R0728/sentences...
# DEBUG   :  make_fwd sentences-R0728-ico-4-fwd.fif...
# DEBUG   :  Raw n-ica: applying ICA for R0729/sentences...
# DEBUG   :  make_fwd sentences-R0729-ico-4-fwd.fif...
# INFO    :  Raw tsss: computing Maxwell filter for R0730/sentences
# INFO    :  Raw n-1-20: filtering for R0730/sentences...
# DEBUG   :  Raw n-ica: applying ICA for R0730/sentences...
# DEBUG   :  make_fwd sentences-R0730-ico-4-fwd.fif...
# DEBUG   :  Make cov-file /Users/maryamvalian/Data/eelbrain-cache/cov/R0730/n-ica emptyroom--cov.fif
# INFO    :  Raw tsss: computing Maxwell filter for R0730/emptyroom
# INFO    :  Raw n-1-20: filtering for R0730/emptyroom...
# DEBUG   :  Raw n-ica: applying ICA for R0730/emptyroom...
# INFO    :  Raw tsss: computing Maxwell filter for R0734/sentences
# INFO    :  Raw n-1-20: filtering for R0734/sentences...
# DEBUG   :  Raw n-ica: applying ICA for R0734/sentences...
# DEBUG   :  make_fwd sentences-R0734-ico-4-fwd.fif...
# DEBUG   :  Make cov-file /Users/maryamvalian/Data/eelbrain-cache/cov/R0734/n-ica emptyroom--cov.fif
# INFO    :  Raw tsss: computing Maxwell filter for R0734/emptyroom
# INFO    :  Raw n-1-20: filtering for R0734/emptyroom...
# DEBUG   :  Raw n-ica: applying ICA for R0734/emptyroom...
# INFO    :  Raw tsss: computing Maxwell filter for R0773/sentences
# INFO    :  Raw n-1-20: filtering for R0773/sentences...
# DEBUG   :  Raw n-ica: applying ICA for R0773/sentences...
# DEBUG   :  make_fwd sentences-R0773-ico-4-fwd.fif...
# DEBUG   :  Make cov-file /Users/maryamvalian/Data/eelbrain-cache/cov/R0773/n-ica emptyroom--cov.fif
# INFO    :  Raw tsss: computing Maxwell filter for R0773/emptyroom
# INFO    :  Raw n-1-20: filtering for R0773/emptyroom...
# DEBUG   :  Raw n-ica: applying ICA for R0773/emptyroom...
# INFO    :  Raw tsss: computing Maxwell filter for R0793/sentences
# INFO    :  Raw n-1-20: filtering for R0793/sentences...
# DEBUG   :  Raw n-ica: applying ICA for R0793/sentences...
# DEBUG   :  make_fwd sentences-R0793-ico-4-fwd.fif...
# DEBUG   :  Make cov-file /Users/maryamvalian/Data/eelbrain-cache/cov/R0793/n-ica emptyroom--cov.fif
# INFO    :  Raw tsss: computing Maxwell filter for R0793/emptyroom
# INFO    :  Raw n-1-20: filtering for R0793/emptyroom...
# DEBUG   :  Raw n-ica: applying ICA for R0793/emptyroom...
# INFO    :  Raw tsss: computing Maxwell filter for R0885/sentences
# INFO    :  Raw n-1-20: filtering for R0885/sentences...
# DEBUG   :  Raw n-ica: applying ICA for R0885/sentences...
# DEBUG   :  make_fwd sentences-R0885-ico-4-fwd.fif...
# DEBUG   :  Make cov-file /Users/maryamvalian/Data/eelbrain-cache/cov/R0885/n-ica emptyroom--cov.fif
# INFO    :  Raw tsss: computing Maxwell filter for R0885/emptyroom
# INFO    :  Raw n-1-20: filtering for R0885/emptyroom...
# DEBUG   :  Raw n-ica: applying ICA for R0885/emptyroom...
# INFO    :  Raw tsss: computing Maxwell filter for R0918/sentences
# INFO    :  Raw n-1-20: filtering for R0918/sentences...
# DEBUG   :  Raw n-ica: applying ICA for R0918/sentences...
# DEBUG   :  make_fwd sentences-R0918-ico-4-fwd.fif...
# DEBUG   :  Make cov-file /Users/maryamvalian/Data/eelbrain-cache/cov/R0918/n-ica emptyroom--cov.fif
# INFO    :  Raw tsss: computing Maxwell filter for R0918/emptyroom
# INFO    :  Raw n-1-20: filtering for R0918/emptyroom...
# DEBUG   :  Raw n-ica: applying ICA for R0918/emptyroom...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       3 for session in sessions:
#       4     e.set(raw='n-ica', epoch=epoch, rej='')
# ----> 6     result=e.load_evoked_stc(
#       7         subjects=group,
#       8         baseline=False,
#       9         cov='emptyroom',
#      10         model='word',
#      11        )
#      12     results[f'{epoch}_{session}'] = result
#
# File ~/Code/Eelbrain/eelbrain/_experiment/mne_experiment.py:3017, in MneExperiment.load_evoked_stc(self, subjects, baseline, src_baseline, cat, keep_evoked, morph, mask, data_raw, vardef, samplingrate, decim, ndvar, **state)
#    3015 fixed = make_kw.get('fixed', False)
#    3016 parc = self.get('parc') or None
# -> 3017 stcs = load.mne.stc_ndvar(stcs, subject, src, mri_sdir, method, fixed, parc=parc, connectivity=self.get('connectivity'))
#    3018 if mask:
#    3019     stcs = _mask_ndvar(stcs)
#
# File ~/Code/Eelbrain/eelbrain/_io/fiff.py:1477, in stc_ndvar(stc, subject, src, subjects_dir, method, fixed, name, check, parc, connectivity, sss_filename)
#    1475     if parc == '':
#    1476         parc = 'aparc'
# -> 1477     ss = SourceSpace(vertices, subject, src, subjects_dir, parc, filename=sss_filename)
#    1478     is_vector = isinstance(stc, mne.VectorSourceEstimate)
#    1479 else:
#
# File ~/Code/Eelbrain/eelbrain/_data_obj.py:10399, in SourceSpace.__init__(self, vertices, subject, src, subjects_dir, parc, connectivity, name, filename)
#   10388 def __init__(
#   10389         self,
#   10390         vertices: List[ArrayLike],
#    (...)  10397         filename: str = '{subject}-{src}-src.fif',
#   10398 ):
# > 10399     SourceSpaceBase.__init__(self, vertices, subject, src, subjects_dir, parc, connectivity, name, filename)
#
# File ~/Code/Eelbrain/eelbrain/_data_obj.py:9901, in SourceSpaceBase.__init__(self, vertices, subject, src, subjects_dir, parc, connectivity, name, filename)
#    9899     self.parc = parc
#    9900 elif isinstance(parc, str):
# -> 9901     self.parc = self._read_parc(parc)
#    9902 else:
#    9903     raise TypeError(f"{parc=}: needs to be Factor or string")
#
# File ~/Code/Eelbrain/eelbrain/_data_obj.py:10417, in SourceSpace._read_parc(self, parc)
#   10413 def _read_parc(self, parc: str) -> Factor:
#   10414     fname = self._ANNOT_PATH.format(
#   10415         subjects_dir=self.subjects_dir, subject=self.subject,
#   10416         hemi='%s', parc=parc)
# > 10417     labels_lh, _, names_lh = read_annot(fname % 'lh')
#   10418     labels_rh, _, names_rh = read_annot(fname % 'rh')
#   10419     x_lh = labels_lh[self.lh_vertices]
#
# File ~/miniforge3/envs/eeldev/lib/python3.12/site-packages/nibabel/freesurfer/io.py:355, in read_annot(filepath, orig_ids)
#     318 def read_annot(filepath, orig_ids=False):
#     319     """Read in a Freesurfer annotation from a ``.annot`` file.
#     320
#     321     An ``.annot`` file contains a sequence of vertices with a label (also known
#    (...)    353         The names of the labels. The length of the list is n_labels.
#     354     """
# --> 355     with open(filepath, 'rb') as fobj:
#     356         dt = _ANNOT_DT
#     358         # number of vertices
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/maryamvalian/Data/mri/fsaverage/label/lh.aparc+aseg.annot'

# %% [markdown]
# # Plot Brain

# %%
subject_id = 'fsaverage'

dipoles_all_timeseries = np.zeros((len(vertices_all_list[0]),res_diff.shape[1],res_diff.shape[2]))


src = mne.read_source_spaces('/Users/maryamvalian/Data/mri/fsaverage/bem/fsaverage-vol-10-src.fif')
stc = mne.VolVectorSourceEstimate(data = dipoles_all_timeseries, vertices=vertices_all_list, tmin=-0.1, tstep=0.005)


brain1 = stc.plot(
    src = src,
    subject = subject_id, 
    subjects_dir=subjects_dir,
    mode = 'stat_map',
    # mode = 'glass_brain',
   # clim = {'kind':'value','lims': [0,5,10]}
)
